# %%
import pandas as pd

# %%
import numpy as np

# %%
faculty={
    'name':['nandu','pandu','chinnu','rajii','nahi','vaishu','sai ','uma','jassu','chindu'],
    'age': [40 ,30 , 45 , 28 , 25 ,32 , 40 , 31 , 29 ,25 ],
    'gender': [' Male ',' Female ',' Female ',' Male ',' Female ',' Male ',' Male ',' Male ',' Male ',' Male '],
    'experince': [9 , 5 , 7 , 9 ,6 , 8 ,9, 6, np.nan ,8 ],
    'salary':[10962490,16929902,9061037,18117922,10190321,21140003,np.nan,8855970,19849098,90136494]
}

# %%
df=pd.DataFrame(faculty)

# %%
df
# Out:
#      name  age    gender  experince      salary
# 0   nandu   40     Male         9.0  10962490.0
# 1   pandu   30   Female         5.0  16929902.0
# 2  chinnu   45   Female         7.0   9061037.0
# 3   rajii   28     Male         9.0  18117922.0
# 4    nahi   25   Female         6.0  10190321.0
# 5  vaishu   32     Male         8.0  21140003.0
# 6    sai    40     Male         9.0         NaN
# 7     uma   31     Male         6.0   8855970.0
# 8   jassu   29     Male         NaN  19849098.0
# 9  chindu   25     Male         8.0  90136494.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       10 non-null     object
#  1   age        10 non-null     int64
#  2   gender     10 non-null     object
#  3   experince  9 non-null      float64
#  4   salary     9 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#              age  experince        salary
# count  10.000000   9.000000  9.000000e+00
# mean   32.500000   7.444444  2.280480e+07
# std     6.851602   1.509231  2.570110e+07
# min    25.000000   5.000000  8.855970e+06
# 25%    28.250000   6.000000  1.019032e+07
# 50%    30.500000   8.000000  1.692990e+07
# 75%    38.000000   9.000000  1.984910e+07
# max    45.000000   9.000000  9.013649e+07

# %%
df.loc[9]
# Out:
# name             chindu
# age                  25
# gender            Male
# experince           8.0
# salary       90136494.0
# Name: 9, dtype: object

# %%
df.isnull().sum()
# Out:
# name         0
# age          0
# gender       0
# experince    1
# salary       1
# dtype: int64
